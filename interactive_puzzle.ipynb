# %%
from aocd.models import Puzzle

y, d = map(lambda x: int(x), ["2025", "1"])
p = Puzzle(year=y, day=d)

print(p.examples)
# Out:
# [Example(input_data='L68\nL30\nR48\nL5\nR60\nL55\nL1\nL99\nR14\nL82', answer_a='3', answer_b='6', extra=None)]

# %%
print(p.examples[0].answer_a)
# Out:
# 3
